# %%
import pandas as pd
df=pd.read_csv('house_prices.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df=df.drop(['Id','MSSubClass'],axis=1)
df
# Out:
#      MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour  \
# 0          RL         65.0     8450   Pave   NaN      Reg         Lvl
# 1          RL         80.0     9600   Pave   NaN      Reg         Lvl
# 2          RL         68.0    11250   Pave   NaN      IR1         Lvl
# 3          RL         60.0     9550   Pave   NaN      IR1         Lvl
# 4          RL         84.0    14260   Pave   NaN      IR1         Lvl
# ...       ...          ...      ...    ...   ...      ...         ...
# 1455       RL         62.0     7917   Pave   NaN      Reg         Lvl
# 1456       RL         85.0    13175   Pave   NaN      Reg         Lvl
# 1457       RL         66.0     9042   Pave   NaN      Reg         Lvl
# 1458       RL         68.0     9717   Pave   NaN      Reg         Lvl
# 1459       RL         75.0     9937   Pave   NaN      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
df=df.drop(['MSZoning','LotFrontage','Street','Alley','LotShape','LandContour','Utilities','LotConfig','LandSlope'],axis=1)
df
# Out:
#       LotArea Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0        8450      CollgCr       Norm       Norm     1Fam     2Story
# 1        9600      Veenker      Feedr       Norm     1Fam     1Story
# 2       11250      CollgCr       Norm       Norm     1Fam     2Story
# 3        9550      Crawfor       Norm       Norm     1Fam     2Story
# 4       14260      NoRidge       Norm       Norm     1Fam     2Story
# ...       ...          ...        ...        ...      ...        ...
# 1455     7917      Gilbert       Norm       Norm     1Fam     2Story
# 1456    13175       NWAmes       Norm       Norm     1Fam     1Story
# 1457     9042      Crawfor       Norm       Norm     1Fam     2Story
# 1458     9717        NAmes       Norm       Norm     1Fam     1Story
# 1459     9937      Edwards       Norm       Norm     1Fam     1Story
#
#       OverallQual  OverallCond  YearBuilt  YearRemodAdd  ... PoolArea PoolQC  \
# ...

# %%
df=df.drop(['Neighborhood','Condition1','Condition2','BldgType','HouseStyle','OverallQual','OverallCond','YearBuilt','YearRemodAdd'],axis=1)
df
# Out:
#       LotArea RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0        8450     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1        9600     Gable  CompShg     MetalSd     MetalSd        NaN
# 2       11250     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3        9550     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4       14260     Gable  CompShg     VinylSd     VinylSd    BrkFace
# ...       ...       ...      ...         ...         ...        ...
# 1455     7917     Gable  CompShg     VinylSd     VinylSd        NaN
# 1456    13175     Gable  CompShg     Plywood     Plywood      Stone
# 1457     9042     Gable  CompShg     CemntBd     CmentBd        NaN
# 1458     9717       Hip  CompShg     MetalSd     MetalSd        NaN
# 1459     9937     Gable  CompShg     HdBoard     HdBoard        NaN
#
#       MasVnrArea ExterQual ExterCond Foundation  ... PoolArea PoolQC  Fence  \
# ...

# %%
df=df.drop(['RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','MasVnrArea','ExterQual','ExterCond','Foundation'],axis=1)
df
# Out:
#       LotArea BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1  \
# 0        8450       Gd       TA           No          GLQ         706
# 1        9600       Gd       TA           Gd          ALQ         978
# 2       11250       Gd       TA           Mn          GLQ         486
# 3        9550       TA       Gd           No          ALQ         216
# 4       14260       Gd       TA           Av          GLQ         655
# ...       ...      ...      ...          ...          ...         ...
# 1455     7917       Gd       TA           No          Unf           0
# 1456    13175       Gd       TA           No          ALQ         790
# 1457     9042       TA       Gd           No          GLQ         275
# 1458     9717       TA       TA           Mn          GLQ          49
# 1459     9937       TA       TA           No          BLQ         830
#
#      BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ... PoolArea PoolQC  \
# ...

# %%
df=df.drop(['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinSF1','BsmtFinType2','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF'],axis=1)
df
# Out:
#       LotArea Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  \
# 0        8450    GasA        Ex          Y      SBrkr       856       854
# 1        9600    GasA        Ex          Y      SBrkr      1262         0
# 2       11250    GasA        Ex          Y      SBrkr       920       866
# 3        9550    GasA        Gd          Y      SBrkr       961       756
# 4       14260    GasA        Ex          Y      SBrkr      1145      1053
# ...       ...     ...       ...        ...        ...       ...       ...
# 1455     7917    GasA        Ex          Y      SBrkr       953       694
# 1456    13175    GasA        TA          Y      SBrkr      2073         0
# 1457     9042    GasA        Ex          Y      SBrkr      1188      1152
# 1458     9717    GasA        Gd          Y      FuseA      1078         0
# 1459     9937    GasA        Gd          Y      SBrkr      1256         0
#
#       LowQualFinSF  GrLivArea  BsmtFullBath  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
df=df.drop(['Heating','HeatingQC','CentralAir','Electrical','1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea'],axis=1)
df
# Out:
#       LotArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0        8450             1             0         2         1             3
# 1        9600             0             1         2         0             3
# 2       11250             1             0         2         1             3
# 3        9550             1             0         1         0             3
# 4       14260             1             0         2         1             4
# ...       ...           ...           ...       ...       ...           ...
# 1455     7917             0             0         2         1             3
# 1456    13175             1             0         2         0             3
# 1457     9042             0             0         2         0             4
# 1458     9717             1             0         1         0             2
# 1459     9937             1             0         1         1             3
#
# ...

# %%
df=df.drop(['BsmtFullBath','BsmtHalfBath','BedroomAbvGr','KitchenAbvGr','KitchenQual','TotRmsAbvGrd','Functional','PoolArea','PoolQC','Fence','MiscFeature','MiscVal','MoSold','YrSold','SaleType','SaleCondition'],axis=1)
df
# Out:
#       LotArea  FullBath  HalfBath  Fireplaces FireplaceQu GarageType  \
# 0        8450         2         1           0         NaN     Attchd
# 1        9600         2         0           1          TA     Attchd
# 2       11250         2         1           1          TA     Attchd
# 3        9550         1         0           1          Gd     Detchd
# 4       14260         2         1           1          TA     Attchd
# ...       ...       ...       ...         ...         ...        ...
# 1455     7917         2         1           1          TA     Attchd
# 1456    13175         2         0           2          TA     Attchd
# 1457     9042         2         0           2          Gd     Attchd
# 1458     9717         1         0           0         NaN     Attchd
# 1459     9937         1         1           0         NaN     Attchd
#
#       GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# ...

# %%
df=pd.read_csv('house_prices.csv')
df=df.drop(['Id','MSSubClass'],axis=1)
df=df.drop(['MSZoning','LotFrontage','Street','Alley','LotShape','LandContour','Utilities','LotConfig','LandSlope'],axis=1)
df=df.drop(['Neighborhood','Condition1','Condition2','BldgType','HouseStyle','OverallQual','OverallCond','YearBuilt','YearRemodAdd'],axis=1)
df=df.drop(['RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','MasVnrArea','ExterQual','ExterCond','Foundation'],axis=1)
df=df.drop(['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinSF1','BsmtFinType2','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF'],axis=1)
df=df.drop(['Heating','HeatingQC','CentralAir','Electrical','1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea'],axis=1)
df=df.drop(['BsmtFullBath','BsmtHalfBath','KitchenAbvGr','KitchenQual','TotRmsAbvGrd','Functional','PoolArea','PoolQC','Fence','MiscFeature','MiscVal','MoSold','YrSold','SaleType','SaleCondition'],axis=1)
df
# Out:
#       LotArea  FullBath  HalfBath  BedroomAbvGr  Fireplaces FireplaceQu  \
# 0        8450         2         1             3           0         NaN
# 1        9600         2         0             3           1          TA
# 2       11250         2         1             3           1          TA
# 3        9550         1         0             3           1          Gd
# 4       14260         2         1             4           1          TA
# ...       ...       ...       ...           ...         ...         ...
# 1455     7917         2         1             3           1          TA
# 1456    13175         2         0             3           2          TA
# 1457     9042         2         0             4           2          Gd
# 1458     9717         1         0             2           0         NaN
# 1459     9937         1         1             3           0         NaN
#
#      GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# ...

# %%
df=df.drop(['Fireplaces','FireplaceQu','GarageType','GarageYrBlt','GarageFinish','GarageCars','GarageArea','GarageQual','GarageCond','PavedDrive','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch'],axis=1)
df
# Out:
#       LotArea  FullBath  HalfBath  BedroomAbvGr  SalePrice
# 0        8450         2         1             3     208500
# 1        9600         2         0             3     181500
# 2       11250         2         1             3     223500
# 3        9550         1         0             3     140000
# 4       14260         2         1             4     250000
# ...       ...       ...       ...           ...        ...
# 1455     7917         2         1             3     175000
# 1456    13175         2         0             3     210000
# 1457     9042         2         0             4     266500
# 1458     9717         1         0             2     142125
# 1459     9937         1         1             3     147500
#
# [1460 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# LotArea         0
# FullBath        0
# HalfBath        0
# BedroomAbvGr    0
# SalePrice       0
# dtype: int64

# %%
X=df.drop(columns='SalePrice')
X
# Out:
#       LotArea  FullBath  HalfBath  BedroomAbvGr
# 0        8450         2         1             3
# 1        9600         2         0             3
# 2       11250         2         1             3
# 3        9550         1         0             3
# 4       14260         2         1             4
# ...       ...       ...       ...           ...
# 1455     7917         2         1             3
# 1456    13175         2         0             3
# 1457     9042         2         0             4
# 1458     9717         1         0             2
# 1459     9937         1         1             3
#
# [1460 rows x 4 columns]

# %%
Y=df['charges']
Y
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'charges'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ...

# %%
Y=df['SalePrice']
Y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
c=lr.intercept_
c
# Out:
# 48030.4681777629

# %%
m=lr.coef_
m
# Out:
# array([ 1.56371339e+00,  7.89482281e+04,  3.54135394e+04, -7.58929307e+03])

# %%
df
# Out:
#       LotArea  FullBath  HalfBath  BedroomAbvGr  SalePrice
# 0        8450         2         1             3     208500
# 1        9600         2         0             3     181500
# 2       11250         2         1             3     223500
# 3        9550         1         0             3     140000
# 4       14260         2         1             4     250000
# ...       ...       ...       ...           ...        ...
# 1455     7917         2         1             3     175000
# 1456    13175         2         0             3     210000
# 1457     9042         2         0             4     266500
# 1458     9717         1         0             2     142125
# 1459     9937         1         1             3     147500
#
# [1460 rows x 5 columns]

# %%
df['Bath']=df['FullBath']+0.5*df['HalfBath']
df
# Out:
#       LotArea  FullBath  HalfBath  BedroomAbvGr  SalePrice  Bath
# 0        8450         2         1             3     208500   2.5
# 1        9600         2         0             3     181500   2.0
# 2       11250         2         1             3     223500   2.5
# 3        9550         1         0             3     140000   1.0
# 4       14260         2         1             4     250000   2.5
# ...       ...       ...       ...           ...        ...   ...
# 1455     7917         2         1             3     175000   2.5
# 1456    13175         2         0             3     210000   2.0
# 1457     9042         2         0             4     266500   2.0
# 1458     9717         1         0             2     142125   1.0
# 1459     9937         1         1             3     147500   1.5
#
# [1460 rows x 6 columns]

# %%
df=df.drop(['FullBath','HalfBath'])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df=df.drop(['FullBath','HalfBath'])
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
df=df.drop(['FullBath','HalfBath'],axis=1)
df
# Out:
#       LotArea  BedroomAbvGr  SalePrice  Bath
# 0        8450             3     208500   2.5
# 1        9600             3     181500   2.0
# 2       11250             3     223500   2.5
# 3        9550             3     140000   1.0
# 4       14260             4     250000   2.5
# ...       ...           ...        ...   ...
# 1455     7917             3     175000   2.5
# 1456    13175             3     210000   2.0
# 1457     9042             4     266500   2.0
# 1458     9717             2     142125   1.0
# 1459     9937             3     147500   1.5
#
# [1460 rows x 4 columns]

# %%
X=df.drop(columns='SalePrice')
X
# Out:
#       LotArea  BedroomAbvGr  Bath
# 0        8450             3   2.5
# 1        9600             3   2.0
# 2       11250             3   2.5
# 3        9550             3   1.0
# 4       14260             4   2.5
# ...       ...           ...   ...
# 1455     7917             3   2.5
# 1456    13175             3   2.0
# 1457     9042             4   2.0
# 1458     9717             2   1.0
# 1459     9937             3   1.5
#
# [1460 rows x 3 columns]

# %%
y=df['SalePrice']

# %%
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.3,random_state=0)

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
c=lr.intercept_
c
# Out:
# 49491.64250641939

# %%
m=lr.coef_
m
# Out:
# array([ 1.57490544e+00, -7.67354005e+03,  7.73137517e+04])

# %%
y_pred_train=lr.predict(X_train)
y_pred_train
# Out:
# array([234520.14014663, 116005.06613409, 122808.6576231 , ...,
#        187488.89132179, 193805.4636346 , 238493.0258102 ])

# %%
df
# Out:
#       LotArea  BedroomAbvGr  SalePrice  Bath
# 0        8450             3     208500   2.5
# 1        9600             3     181500   2.0
# 2       11250             3     223500   2.5
# 3        9550             3     140000   1.0
# 4       14260             4     250000   2.5
# ...       ...           ...        ...   ...
# 1455     7917             3     175000   2.5
# 1456    13175             3     210000   2.0
# 1457     9042             4     266500   2.0
# 1458     9717             2     142125   1.0
# 1459     9937             3     147500   1.5
#
# [1460 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(y_train,y_pred_train)
plt.xlabel("Actual Charges")
plt.ylabel("Predicted Charges")
plt.show()

# %%
from sklearn.metrics import r2_score
r2_score(y_train,y_pred_train)
# Out:
# 0.4144673262736215

# %%
df
# Out:
#       LotArea  BedroomAbvGr  SalePrice  Bath
# 0        8450             3     208500   2.5
# 1        9600             3     181500   2.0
# 2       11250             3     223500   2.5
# 3        9550             3     140000   1.0
# 4       14260             4     250000   2.5
# ...       ...           ...        ...   ...
# 1455     7917             3     175000   2.5
# 1456    13175             3     210000   2.0
# 1457     9042             4     266500   2.0
# 1458     9717             2     142125   1.0
# 1459     9937             3     147500   1.5
#
# [1460 rows x 4 columns]

# %%
y_pred_test=lr.predict(X_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred_test)
plt.xlabel("Actual Charges")
plt.ylabel("Predicted Charges")
plt.show()

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred_test)
# Out:
# 0.3836201850524591

# %%
df=pd.read_csv('house_prices.csv')
df=df.drop(['Id','MSSubClass'],axis=1)
df=df.drop(['MSZoning','LotFrontage','Street','Alley','LotShape','LandContour','Utilities','LotConfig','LandSlope'],axis=1)
df=df.drop(['Neighborhood','Condition1','Condition2','BldgType','HouseStyle','OverallQual','OverallCond','YearBuilt','YearRemodAdd'],axis=1)
df=df.drop(['RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','MasVnrArea','ExterQual','ExterCond','Foundation'],axis=1)
df=df.drop(['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinSF1','BsmtFinType2','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF'],axis=1)
df=df.drop(['Heating','HeatingQC','CentralAir','Electrical','1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea'],axis=1)
df=df.drop(['BsmtFullBath','BsmtHalfBath','KitchenAbvGr','KitchenQual','TotRmsAbvGrd','Functional','PoolArea','PoolQC','Fence','MiscFeature','MiscVal','MoSold','YrSold','SaleType','SaleCondition'],axis=1)
df
# Out:
#       LotArea  FullBath  HalfBath  BedroomAbvGr  Fireplaces FireplaceQu  \
# 0        8450         2         1             3           0         NaN
# 1        9600         2         0             3           1          TA
# 2       11250         2         1             3           1          TA
# 3        9550         1         0             3           1          Gd
# 4       14260         2         1             4           1          TA
# ...       ...       ...       ...           ...         ...         ...
# 1455     7917         2         1             3           1          TA
# 1456    13175         2         0             3           2          TA
# 1457     9042         2         0             4           2          Gd
# 1458     9717         1         0             2           0         NaN
# 1459     9937         1         1             3           0         NaN
#
#      GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# ...

# %%
df=df.drop(['Fireplaces','FireplaceQu','GarageType','GarageYrBlt','GarageFinish','GarageCars','GarageArea','GarageQual','GarageCond','PavedDrive','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch'],axis=1)
df
# Out:
#       LotArea  FullBath  HalfBath  BedroomAbvGr  SalePrice
# 0        8450         2         1             3     208500
# 1        9600         2         0             3     181500
# 2       11250         2         1             3     223500
# 3        9550         1         0             3     140000
# 4       14260         2         1             4     250000
# ...       ...       ...       ...           ...        ...
# 1455     7917         2         1             3     175000
# 1456    13175         2         0             3     210000
# 1457     9042         2         0             4     266500
# 1458     9717         1         0             2     142125
# 1459     9937         1         1             3     147500
#
# [1460 rows x 5 columns]

# %%
X=df.drop(columns='SalePrice')
X
# Out:
#       LotArea  FullBath  HalfBath  BedroomAbvGr
# 0        8450         2         1             3
# 1        9600         2         0             3
# 2       11250         2         1             3
# 3        9550         1         0             3
# 4       14260         2         1             4
# ...       ...       ...       ...           ...
# 1455     7917         2         1             3
# 1456    13175         2         0             3
# 1457     9042         2         0             4
# 1458     9717         1         0             2
# 1459     9937         1         1             3
#
# [1460 rows x 4 columns]

# %%
y=df['SalePrice']
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.3,random_state=0)
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
c=lr.intercept_
c
# Out:
# 48030.4681777629

# %%
m=lr.coef_
m
# Out:
# array([ 1.56371339e+00,  7.89482281e+04,  3.54135394e+04, -7.58929307e+03])

# %%
y_pred_train=lr.predict(X_train)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_train,y_pred_train)
plt.xlabel("Actual Charges")
plt.ylabel("Predicted Charges")
plt.show()

# %%
from sklearn.metrics import r2_score
r2_score(y_train,y_pred_train)
# Out:
# 0.41495829865855893

# %%
y_pred_test=lr.predict(X_test)
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred_test)
plt.xlabel("Actual Charges")
plt.ylabel("Predicted Charges")
plt.show()

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred_test)
# Out:
# 0.3828972402607498

# %%
df
# Out:
#       LotArea  FullBath  HalfBath  BedroomAbvGr  SalePrice
# 0        8450         2         1             3     208500
# 1        9600         2         0             3     181500
# 2       11250         2         1             3     223500
# 3        9550         1         0             3     140000
# 4       14260         2         1             4     250000
# ...       ...       ...       ...           ...        ...
# 1455     7917         2         1             3     175000
# 1456    13175         2         0             3     210000
# 1457     9042         2         0             4     266500
# 1458     9717         1         0             2     142125
# 1459     9937         1         1             3     147500
#
# [1460 rows x 5 columns]

# %%
new_data = pd.DataFrame([[8450, 2, 1, 3]], columns=['LotArea', 'FullBath', 'HalfBath', 'BedroomAbvGr'])

# Predict price for new_data
predicted_price = model.predict(new_data)
print(f'Predicted Price for New Property: {predicted_price[0]}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 4
#       1 new_data = pd.DataFrame([[8450, 2, 1, 3]], columns=['LotArea', 'FullBath', 'HalfBath', 'BedroomAbvGr'])
#       3 # Predict price for new_data
# ----> 4 predicted_price = model.predict(new_data)
#       5 print(f'Predicted Price for New Property: {predicted_price[0]}')
#
# NameError: name 'model' is not defined

# %%
new_data = pd.DataFrame([[8450, 2, 1, 3]], columns=['LotArea', 'FullBath', 'HalfBath', 'BedroomAbvGr'])

# Predict price for new_data
predicted_price = lr.predict(new_data)
print(f'Predicted Price for New Property: {predicted_price[0]}')
# Out:
# Predicted Price for New Property: 231785.96269116498
